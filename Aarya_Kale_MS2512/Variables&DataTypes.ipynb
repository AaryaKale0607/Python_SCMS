# %% [markdown]
# ## Variables and Data Types

# %%
#Creating variables of different types
name = "Alice"          #String
age = 25                #Integer
height = 5.6            #Float
is_student = True       #Boolean

#Print the variables and their types 
print(f"Name: {name}, Type: {type(name)}")
print(f"Age: {age} , Type: {type(age)}")
print(f"Height: {height} , Type: {type(height)}")
print(f"Is_Student: {is_student} , Type: {type(is_student)}")
# Out:
# Name: Alice, Type: <class 'str'>
# Age: 25 , Type: <class 'int'>
# Height: 5.6 , Type: <class 'float'>
# Is_Student: True , Type: <class 'bool'>

# %%
print(f"Hello World, {name}, {age}")
# Out:
# Hello World, Alice, 25

# %% [markdown]
# ## Basic Operations

# %%
# Arithmetic Operations
a = 7
b = 6

print(f"Addition: {a} + {b} = {a + b}")
print(f"Subtraction: {a} - {b} = {a - b}")
print(f"Multiplication: {a} * {b} = {a * b}")
print(f"Division: {a} / {b} = {a / b}")

print(f"Floor Division: {a} // {b} = {a // b}")
print(f"Modulus: {a} % {b} = {a % b}")
print(f"Power: {a} ** {b} = {a ** b}")
# Out:
# Addition: 7 + 6 = 13
# Subtraction: 7 - 6 = 1
# Multiplication: 7 * 6 = 42
# Division: 7 / 6 = 1.1666666666666667
# Floor Division: 7 // 6 = 1
# Modulus: 7 % 6 = 1
# Power: 7 ** 6 = 117649

# %% [markdown]
# ## Comparison and Logical Operators

# %%
x = 5
y = 10

print(f"x == y: {x == y}")
print(f"x < y: {x < y}")
print(f"x > y: {x > y}")
print(f"x != y: {x != y}")

# Logical Operators
print(f"(x < y) and (x > 0): {(x < y) and (x > 0)}")
print(f"(x > y) or (x > 0): {(x > y) or (x > 0)}")
print(f"not (x == y): {not (x == y)}")
# Out:
# x == y: False
# x < y: True
# x > y: False
# x != y: True
# (x < y) and (x > 0): True
# (x > y) or (x > 0): True
# not (x == y): True

# %% [markdown]
# ## Input and Output

# %%
user_name = (input("Can you enter your name: "))
print(f"The user name is {user_name} and the type is {type(user_name)}")
print(type(user_name))
user_age = input("Enter your age: ")
print(f"The user age is {user_age} and type is {type(user_age)}")
user_age = int(user_age)

print(f"Hello, {user_name}! You are {user_age} years old.")
print(f"Next year , you will be {user_age + 1} years old.")
# Out:
# The user name is Aarya and the type is <class 'str'>
# <class 'str'>
# The user age is 22 and type is <class 'str'>
# Hello, Aarya! You are 22 years old.
# Next year , you will be 23 years old.

# %% [markdown]
# ## Strings and String Methods

# %%
# Creating Strings
message ="Hello , Python Programming !"
name = "James Bond"

print(f"Original Message: {message}")
print(f"Length: {len(message)}")
print(f"Uppercase: {message.upper()}")
print(f"Lowercase: {message.lower()}")
print(f"Capitalized Name: {name.title()}")
print(f"Replace 'Python' with 'World': {message.replace('Python' , 'World')}")
# Out:
# Original Message: Hello , Python Programming !
# Length: 28
# Uppercase: HELLO , PYTHON PROGRAMMING !
# Lowercase: hello , python programming !
# Capitalized Name: James Bond
# Replace 'Python' with 'World': Hello , World Programming !

# %%
# String slicing and indexing

text = "Python"
