# %% [markdown]
# ## Pandas Workbook

# %% [markdown]
# students = [
#     ["Aarav", 85, 78, 92],
#     ["Riya", 91, 88, 95],
#     ["Kabir", 72, 69, 80],
# ]

# %%
# code here
students = [
    ["Aarav" , 85, 78 , 92],
    ["Riya" , 91, 88, 95],
    ["Kabir",72, 69 , 80]
]

print(students)
# Out:
# [['Aarav', 85, 78, 92], ['Riya', 91, 88, 95], ['Kabir', 72, 69, 80]]

# %% [markdown]
# ### can you answer these question based on the code above ?
# What does 85 represent?
#
# How do I get all the Maths marks?
#
# How do I get Riya's marks?
#
# What if I add 20 more students?
#
# What if one student has a missing mark?
#
# What if I want to filter students with average > 80?

# %% [markdown]
# | Name  | Maths | Physics | Python |
# | ----- | ----: | ------: | -----: |
# | Aarav |    85 |      78 |     92 |
# | Riya  |    91 |      88 |     95 |
# | Kabir |    72 |      69 |     80 |

# %% [markdown]
# ## what does pandas give us?
#
# **Series  →  one column**
#
# **DataFrame →  complete table**

# %% [markdown]
# ## Creating a DataFrame
#
# A Pandas DataFrame is a two-dimensional labelled data structure.
#
# Let's create one from a dictionary.

# %% [markdown]
# ############################################

# %% [markdown]
# import pandas as pd

# %%
import pandas as pd

# %% [markdown]
# students = [
#     ["Alice", 21, "Pune", 85],
#     ["Bob", 22, "Mumbai", 91],
#     ["Charlie", 20, "Pune", 78]
# ]
#
# df = pd.DataFrame(
#     students,
#     columns=["Name", "Age", "City", "Score"]
# )
#
# df

# %%
# code here
students = [
    ["Alice", 21, "Pune", 85],
    ["Bob", 22, "Mumbai", 91],
    ["Charlie", 20, "Pune", 78]
]
print(students)

df = pd.DataFrame(
    students,
    columns=["Name", "Age", "City", "Score"]
)
print('\n')
print(df)
# Out:
# [['Alice', 21, 'Pune', 85], ['Bob', 22, 'Mumbai', 91], ['Charlie', 20, 'Pune', 78]]
#
#
#       Name  Age    City  Score
# 0    Alice   21    Pune     85
# 1      Bob   22  Mumbai     91
# 2  Charlie   20    Pune     78

# %% [markdown]
# ## Understanding a DataFrame
#
# Before we start manipulating data, let's understand the basic structure of a DataFrame.
#
# A DataFrame consists of:
#
# - **Rows** — individual observations or records
# - **Columns** — variables or attributes
# - **Index** — labels used to identify rows
#
# For our DataFrame:
#
# | Index | Name | Age | City | Score |
# |------:|------|----:|------|------:|
# | 0 | Alice | 21 | Pune | 85 |
# | 1 | Bob | 22 | Mumbai | 91 |
# | 2 | Charlie | 20 | Pune | 78 |
#
# The index is automatically created by Pandas when we create the DataFrame.
#
# Let's inspect some basic properties of our DataFrame.

# %% [markdown]
# ### Try this with the df you have created and see what all output you get?
#
# df.head()
#
# df.tail()
#
# df.shape
#
# df.columns
#
# df.index
#
# df.dtypes
#
# df.info()
#
# df.describe()

# %%
#code here

### Try this with the df you have created and see what all output you get?

#df.head(1)

# df.tail(1)

# df.shape

# df.columns

# df.index

# df.dtypes

df.info()

# df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   City    3 non-null      object
#  3   Score   3 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 224.0+ bytes

# %% [markdown]
# ## Selecting Columns
#
# A DataFrame contains multiple columns, but often we are interested in only a few of them.
#
# For example, suppose we only want to look at the students' names.
#
# We can select a column using its column name:
#
# ```python

# %% [markdown]
# df["Name"]

# %%
#code here
df["Name"]
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# Name: Name, dtype: object

# %% [markdown]
# ### What did we get?
#
# Notice that the result is **not another DataFrame**.
#
# It is a Pandas **Series**.
#
# A `Series` is a one-dimensional labelled data structure in Pandas.
#
# You can think of it as a **single column** of a DataFrame.

# %% [markdown]
# ### DataFrame vs Series
#
# The relationship can be visualised like this:
#
# ```text
# DataFrame
# ┌───────┬─────────┬─────┬────────┬───────┐
# │ Index │ Name    │ Age │ City   │ Score │
# ├───────┼─────────┼─────┼────────┼───────┤
# │   0   │ Alice   │ 21  │ Pune   │  85   │
# │   1   │ Bob     │ 22  │ Mumbai │  91   │
# │   2   │ Charlie │ 20  │ Pune   │  78   │
# └───────┴─────────┴─────┴────────┴───────┘
#
#               ↓ select one column
#
# Series
# ┌───────┬─────────┐
# │ Index │ Name    │
# ├───────┼─────────┤
# │   0   │ Alice   │
# │   1   │ Bob     │
# │   2   │ Charlie │
# └───────┴─────────┘

# %% [markdown]
# ### Markdown cell
#
# ```markdown
# ## Selecting Multiple Columns
#
# What if we want both `Name` and `Score`?
#
# We can pass a **list of column names** inside the square brackets:
#
# ```python
# df[["Name", "Score"]]

# %%
#code here
df[["Name", "Score"]]
# Out:
#       Name  Score
# 0    Alice     85
# 1      Bob     91
# 2  Charlie     78

# %%
df[["City"]]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   City    3 non-null      object
#  3   Score   3 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 224.0+ bytes

# %%
df[["Age"]]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   City    3 non-null      object
#  3   Score   3 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 224.0+ bytes

# %%
df[["Name" , "City"]]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   City    3 non-null      object
#  3   Score   3 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 224.0+ bytes

# %%
df[["Name" , "Age" , "Score"]]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   City    3 non-null      object
#  3   Score   3 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 224.0+ bytes

# %% [markdown]
# ### 🧠 Try It Yourself
#
# Using `df`, select:
#
# 1. Only the `City` column.
# 2. Only the `Age` column.
# 3. The `Name` and `City` columns.
# 4. The `Name`, `Age`, and `Score` columns.
#
# Then check the type of the result for a single column and for multiple columns.
#
# **Question:** Why do you think Pandas returns a Series when selecting one column but a DataFrame when selecting multiple columns?

# %% [markdown]
# ########################################################################

# %% [markdown]
# ## Selecting Rows
#
# So far, we have learned how to select columns.
#
# But what if we want to select specific **rows**?
#
# Pandas provides two important tools for selecting rows:
#
# - `iloc` — select using the **position** of the row
# - `loc` — select using the **label** of the row
#
# Let's start with `iloc`.

# %% [markdown]
# ### `iloc` — Integer Position Based Selection
#
# `iloc` stands for **integer-location**.
#
# It allows us to select rows and columns based on their **numerical position**.
#
# Remember that our DataFrame has the following row positions:
#
# | Position | Index | Name |
# |---:|---:|---|
# | 0 | 0 | Alice |
# | 1 | 1 | Bob |
# | 2 | 2 | Charlie |
#
# To select the first row:

# %% [markdown]
# ```python
# df.iloc[0]

# %%
#code here
df.iloc[2]
# Out:
# Name     Charlie
# Age           20
# City        Pune
# Score         78
# Name: 2, dtype: object

# %% [markdown]
# The result is a **Series** containing the values from that row.
#
# Just like selecting a single column:
#
# ```python
# df["Name"]

# %% [markdown]
# #### Selecting Multiple Rows

# %% [markdown]
# df.iloc[0:2]

# %%
#code here
df.iloc[0:2]
# Out:
#     Name  Age    City  Score
# 0  Alice   21    Pune     85
# 1    Bob   22  Mumbai     91

# %% [markdown]
# ### Selecting a Specific Row and Column
#
# `iloc` can also be used to select both rows and columns.
#
# The general syntax is:
#
# ```python
# df.iloc[row, column]

# %% [markdown]
# df.iloc[0, 1]

# %%
#code here
df.iloc[1,2]
# Out:
# 'Mumbai'

# %% [markdown]
# We can also select a range of rows and columns:
#
# ```python
# df.iloc[0:2, 0:2]

# %%
#code here 
df.iloc[0:2, 0:2]
# Out:
#     Name  Age
# 0  Alice   21
# 1    Bob   22

# %%
df.iloc[1]
# Out:
# Name        Bob
# Age          22
# City     Mumbai
# Score        91
# Name: 1, dtype: object

# %%
df.iloc[-1]
# Out:
# Name     Charlie
# Age           20
# City        Pune
# Score         78
# Name: 2, dtype: object

# %%
df.iloc[0:2]
# Out:
#     Name  Age    City  Score
# 0  Alice   21    Pune     85
# 1    Bob   22  Mumbai     91

# %%
df.iloc[0:2, 0:2]
# Out:
#     Name  Age
# 0  Alice   21
# 1    Bob   22

# %%
df.iloc[1,3]
# Out:
# 91

# %% [markdown]
# ### 🧠 Try It Yourself
#
# Using `iloc`, try to:
#
# 1. Select the second row.
# 2. Select the last row.
# 3. Select the first two rows.
# 4. Select the `Name` and `Age` columns of the first two rows.
# 5. Select the value `91` directly using its row and column position.
#
# **Hint:** Remember that indexing starts from `0`.

# %% [markdown]
# ## `loc` — Label-Based Selection
#
# `loc` is used to select data based on **labels**.
#
# The important distinction is:
#
# > `iloc` → **position**
# > `loc` → **label**
#
# So far, our DataFrame has the default index:
#
# | Index | Name | Age | City | Score |
# |------:|------|----:|------|------:|
# | 0 | Alice | 21 | Pune | 85 |
# | 1 | Bob | 22 | Mumbai | 91 |
# | 2 | Charlie | 20 | Pune | 78 |
#
# Here, the index values (`0`, `1`, `2`) are also labels.
#
# For example:

# %% [markdown]
# ```python
# df.loc[0]

# %%
#code here
df.loc[0]
# Out:
# Name     Alice
# Age         21
# City      Pune
# Score       85
# Name: 0, dtype: object

# %% [markdown]
# ### `loc` vs `iloc`
#
# With our current DataFrame, these may appear to do the same thing:
#
# ```python
# df.loc[0]
# df.iloc[0]

# %%
df.loc[0]
df.iloc[0]
# Out:
# Name     Alice
# Age         21
# City      Pune
# Score       85
# Name: 0, dtype: object

# %% [markdown]
# ### Code cell
#
# ```python
# df_custom = df.copy()
#
# df_custom.index = ["student_A", "student_B", "student_C"]
#
# df_custom

# %%
df_custom = df.copy()

df_custom.index = ["student_A", "student_B", "student_C"]

df_custom
# Out:
#               Name  Age    City  Score
# student_A    Alice   21    Pune     85
# student_B      Bob   22  Mumbai     91
# student_C  Charlie   20    Pune     78

# %% [markdown]
# Now our DataFrame looks like:
#
# | Index | Name | Age | City | Score |
# |---|---|---:|---|---:|
# | student_A | Alice | 21 | Pune | 85 |
# | student_B | Bob | 22 | Mumbai | 91 |
# | student_C | Charlie | 20 | Pune | 78 |
#
# Now let's select Bob.
#
# Using `loc`, we can directly use his row label:
#
# ```python
# df_custom.loc["student_B"]

# %%
#code here
df_custom.loc["student_B"]
# Out:
# Name        Bob
# Age          22
# City     Mumbai
# Score        91
# Name: student_B, dtype: object

# %% [markdown]
# But `iloc` still works with the **position**:
#
# ```python
# df_custom.iloc[1]

# %%
#code here
df_custom.iloc[1]
# Out:
# Name        Bob
# Age          22
# City     Mumbai
# Score        91
# Name: student_B, dtype: object

# %% [markdown]
# iloc → position
#
#         ↓
#         1st / 2nd / 3rd ...
#
# loc  → label
#
#         ↓
#         student_A / student_B / student_C

# %% [markdown]
# ### Markdown cell
#
# ```markdown
# ## Selecting Rows and Columns with `loc`
#
# Just like `iloc`, `loc` can select both rows and columns.
#
# The general syntax is:

# %%
#code here
df_custom.loc["student_B", "Score"]
# Out:
# 91

# %% [markdown]
# We can also select multiple columns:
#
# ```python
# df_custom.loc["student_B", ["Name", "City", "Score"]]

# %%
#code here
df_custom.loc["student_B", ["Name", "City", "Score"]]
# Out:
# Name        Bob
# City     Mumbai
# Score        91
# Name: student_B, dtype: object

# %% [markdown]
# ### Selecting Multiple Rows with `loc`
#
# We can provide a list of row labels:
#
# ```python
# df_custom.loc[["student_A", "student_C"]]

# %%
df_custom.loc[["student_A", "student_C"]]
# Out:
#               Name  Age  City  Score
# student_A    Alice   21  Pune     85
# student_C  Charlie   20  Pune     78

# %%
df_custom.loc[["student_A"]]
# Out:
#             Name  Age  City  Score
# student_A  Alice   21  Pune     85

# %%
df_custom.loc["student_C" , ["City"]]
# Out:
# City    Pune
# Name: student_C, dtype: object

# %%
df_custom.loc["student_B" , ["Name" , "Score"]]
# Out:
# Name     Bob
# Score     91
# Name: student_B, dtype: object

# %%
df_custom.loc[["student_A" , "student_C"]]
# Out:
#               Name  Age  City  Score
# student_A    Alice   21  Pune     85
# student_C  Charlie   20  Pune     78

# %%
df_custom.loc['student_A':'student_B']
# Out:
#             Name  Age    City  Score
# student_A  Alice   21    Pune     85
# student_B    Bob   22  Mumbai     91

# %%
df_custom.loc[["student_A" , "student_C"] , ["Name" , "Score"]]
# Out:
#               Name  Score
# student_A    Alice     85
# student_C  Charlie     78

# %% [markdown]
# ### 🧠 Try It Yourself
#
# Using `df_custom` and `loc`, try to:
#
# 1. Select `student_A`.
# 2. Select the `City` of `student_C`.
# 3. Select the `Name` and `Score` of `student_B`.
# 4. Select `student_A` and `student_C`.
# 5. Select all rows from `student_A` through `student_B`, including both.
# 6. Select the `Name` and `Score` columns for `student_A` and `student_C`.
#
# ### Remember
#
# ```text
# iloc → integer position
# loc  → label
